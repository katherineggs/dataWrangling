# %%
# LABORATORIO 2

# %%
import numpy as np
import pandas as pd

# %%
# Leemos el csv
heroes = pd.read_csv("heroes_information.csv")

# %%
# Comprobamos
heroes
# Out:
#       id             name  Gender Eye color               Race  \
# 0      0           A-Bomb    Male    yellow              Human
# 1      1       Abe Sapien    Male      blue      Icthyo Sapien
# 2      2         Abin Sur    Male      blue            Ungaran
# 3      3      Abomination    Male     green  Human / Radiation
# 4      4          Abraxas    Male      blue      Cosmic Entity
# ..   ...              ...     ...       ...                ...
# 729  729  Yellowjacket II  Female      blue              Human
# 730  730             Ymir    Male     white        Frost Giant
# 731  731             Yoda    Male     brown     Yoda's species
# 732  732          Zatanna  Female      blue              Human
# 733  733             Zoom    Male       red                NaN
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# 0             No Hair   203.0      Marvel Comics        NaN      good   441.0
# ...

# %%
from pandasql import *

sqlDf = lambda q: sqldf(q,globals())

# %%
# Primer nombre 
query = """ 
SELECT name FROM heroes 
LIMIT 1
"""

sqlDf(query)
# Out:
#      name
# 0  A-Bomb

# %%
# Casas Publicadoras
query = """
SELECT Publisher, COUNT(*) FROM heroes
GROUP BY (Publisher)
"""

sqlDf(query)
# Out:
#             Publisher  COUNT(*)
# 0                None        15
# 1         ABC Studios         4
# 2           DC Comics       215
# 3   Dark Horse Comics        18
# 4        George Lucas        14
# 5       Hanna-Barbera         1
# 6       HarperCollins         6
# 7      IDW Publishing         4
# 8         Icon Comics         4
# 9        Image Comics        14
# 10      J. K. Rowling         1
# 11   J. R. R. Tolkien         1
# 12      Marvel Comics       388
# 13          Microsoft         1
# 14       NBC - Heroes        19
# 15          Rebellion         1
# 16           Shueisha         4
# 17      Sony Pictures         2
# 18         South Park         1
# 19          Star Trek         6
# 20               SyFy         5
# 21       Team Epic TV         5
# 22        Titan Books         1
# 23  Universal Studios         1
# 24          Wildstorm         3

# %%
# CUANTOS Superheores de 2m
query = """
SELECT COUNT(*) FROM heroes
WHERE Height > 200
"""

sqlDf(query)
# Out:
#    COUNT(*)
# 0        59

# %%
# CUANTOS Superheores de 2m y humanos
query = """
SELECT COUNT(*) FROM heroes
WHERE (Height > 200) and (Race = "Human")
"""

sqlDf(query)
# Out:
#    COUNT(*)
# 0        12

# %%
# CUANTOS Peso más de 100 lbs y menos de 200 lbs
query = """
SELECT COUNT(*) FROM heroes
WHERE (Weight > 100) and (Weight < 200)
"""

sqlDf(query)
# Out:
#    COUNT(*)
# 0        98

# %%
# CUANTOS Ojos de color azul o rojo
query = """
SELECT "Eye color", COUNT(*) FROM heroes
WHERE "Eye color" IN ("red", "blue")
GROUP BY "Eye color"
"""

sqlDf(query)
# Out:
#   Eye color  COUNT(*)
# 0      blue       225
# 1       red        46

# %%
# CUANTOS Human, Mutant y tienen el pelo color Verde o son Vampiros con pelo Negro
query = """
SELECT name, Race, "Hair color" FROM heroes
WHERE Race IN ("Human", "Mutant") 
AND "Hair color" IN ("Green")

OR Race IN ("Vampire") 
AND "Hair color" IN ("Black")
"""

sqlDf(query)
# Out:
#         name     Race Hair color
# 0  Beast Boy    Human      Green
# 1      Blade  Vampire      Black
# 2      Joker    Human      Green
# 3    Polaris   Mutant      Green
# 4   She-Hulk    Human      Green

# %%
# Primer superhéroe si ordeno la tabla por raza en orden descendente
query = """
SELECT name FROM heroes
ORDER BY Race DESC
limit 1
"""

sqlDf(query)
# Out:
#              name
# 0  Solomon Grundy

# %%
# Superhéroes son de género masculino y cuántas de género femenino
query = """
SELECT Gender, COUNT(*) FROM heroes
GROUP BY Gender
"""

sqlDf(query)
# Out:
#    Gender  COUNT(*)
# 0    None        29
# 1  Female       200
# 2    Male       505

# %%
# Casas publicadoras tienen más de 15 superhéroes
query = """
SELECT Publisher, COUNT(*) FROM heroes
GROUP BY Publisher 
HAVING COUNT(*) > 15
"""

sqlDf(query)
# Out:
#            Publisher  COUNT(*)
# 0          DC Comics       215
# 1  Dark Horse Comics        18
# 2      Marvel Comics       388
# 3       NBC - Heroes        19
